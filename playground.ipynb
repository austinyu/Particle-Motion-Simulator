# %%
# %matplotlib notebook
import numpy as np

# %%
from particle_motion import Particle_Motion

# %%
demo = Particle_Motion()
demo_params = [("exp1", 
                    {'charge' : 1, 
                        'mass' : 1, 
                        'b_field' : lambda x, y, z: [1,0,0],  
                        'e_field' : lambda x, y, z: [0,0,0]},
                    initial_state = np.array([0, 0, 0, 1, 1, 0])), 
                ("exp2", 
                    {'charge' : 1,
                        'mass' : 1,
                        'b_field' : lambda x, y, z: [1,0,0],
                        'e_field' : lambda x, y, z: [0,0,0]},
                    initial_state = np.array([0, 0, 0, 1, 1, 0])),
                ("exp3", 
                    {'charge' : 1,
                        'mass' : 1,
                        'b_field' : lambda x, y, z: [1,0,0],
                        'e_field' : lambda x, y, z: [0,0,0]},
                initial_state = np.array([0, 0, 0, 1, 1, 0]))]
for name, params, initial_state in charge_experiment_params:
    charge_comp.run_experiment(name, params = params, initial_state = initial_state)
# Out:
# <img src="data:image/png;base64,..." width="640">
